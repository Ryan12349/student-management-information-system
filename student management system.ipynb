# %% [markdown]
# STUDENT MANAGEMENT SYSYTEM

# %%
##### students = []
def add_student():
    name = input("Enter your name:")
    age = int(input("Enter age:"))
    marks = float(input("Marks:"))
    student = {
        "name":name,
        "age":age,
        "marks":marks
    }
    students.append(student)
    print("Student added")
    print()
def view_students():
    if(Students) ==0:
        print("No student found")
        print()
        return
    i=1
    for student in students:
        print(i)
        print("Name:",student["name"])
        print("Age:",student["age"])
        print("Marks:",student["marks"])
        print("-------------------")
        i+=1
    print()
def search_student():
    search_name = input("Enter the name:")
    found = False
    for student in students:
        if student["name"] == search_name:
            print("student name found")
            print("Name:",student["name"])
            print("Age:",student["age"])
            print("Marks:",student["marks"])
            print("-------------------")
            found = True
            break
        if found == False:
            print("student not found")
            print()
def average_marks():
    if len(students) == 0:
        print("No student to calculate average")
        print()
        return
    total = 0
    for student in students:
        total = total + student["marks"]
    average = tatal/len(students)
    print("Average is :",average)
    print()
while True:
    print("Student management system")
    print("1 Add student")
    print("2 view student")
    print("3 search student")
    print("4 Average marks") 
    print("5 Exit")
    choice = input("Choose a number")
    if choice == "1":
        add_student()
    elif choice == "2":
        view_student()
    elif choice == "3":
        search_student()
    elif choice == "4":
        average_marks()
    elif choice == "5":
        print("Bye Bye")
        break
    else:
        print("Invalide choice")
# Out:
# Student management system
# 1 Add student
# 2 view student
# 3 search student
# 4 Average marks
# 5 Exit
